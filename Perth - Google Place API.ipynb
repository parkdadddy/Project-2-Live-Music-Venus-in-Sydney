# %%
# Dependencies
import requests
import pandas as pd

url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9505,115.8605&radius=3000&type=liquor_store&pagetoken=CrQCIQEAAKVSWrz5Z4PWgTGVSuKUDZEy5_Jf0GHNY6rkAaw4WqKKqvDR6LHJWiEMpqEKKD-BJeAl5UPyjGhSdfBQCDQbF5nbXcq45lX2h8KyYnR77yohrowzbPj77H7raATvQPnebxneczD0pbCn0xjBvzMmQ_TAVV7zVR0cw317lAtN1Yq8UIttCksCcmtYhBHwTfMTqZ70r0QyqshxlW4AP1bRN5-2MBQtMl6KymMa8SNzISAdsJFVPPF4fdRU3OjxhGj6yBFaxc0xwoypW1UJGqO7kHSdcccWNt2qymEu1xWq-rG3UOxfUEbQAJB3UIx5JBBRaK0ndFkO3JFJtwrVvxkrWFbc5bKa7Uoi7E6cep4FF9BAuTSWQCeqeFLNBgw4KqwqyJNCplmtQF4aAaqiHjqlDCsSEH6hI5qLINLGHvAU__3vS0QaFCllHh2KJLOKOJmN-gPM6ZyRhLXD"

# %%
# bottle_shop_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=liquor_store"
# kc_bottle_shops = requests.get(bottle_shop_url).json()

# print(sydney_bottle_shops['next_page_token'])

# for x in range(2):
init_bottle_shop_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9505,115.8605&radius=3000&type=liquor_store"

kc_bottle_shops = requests.get(init_bottle_shop_url).json()

for bottle_shop in kc_bottle_shops:
#             print(kc_bottle_shops)
#             print('--------------------------------------')
#             print(kc_bottle_shops['next_page_token'])
            next_bottle_shop_url = init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])
            #second page url 
#             print('--------------------------------------')
#             print(next_bottle_shop_url)
#             print('--------------------------------------')
            next_bottle_shop_url = f'{next_bottle_shop_url}'

            
# next_kc_bottle_shops = requests.get(init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])).json()
            
        
result_1 = kc_bottle_shops['results']
result_1
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.9730981, 'lng': 115.8523315},
#    'viewport': {'northeast': {'lat': -31.9718064197085,
#      'lng': 115.8536386802915},
#     'southwest': {'lat': -31.9745043802915, 'lng': 115.8509407197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'name': 'The Windsor Hotel',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111571283293348134703">The Windsor Hotel</a>'],
#     'photo_reference': 'CmRaAAAAinUBXmuXK0ClcFtaRcVcDxkvQo4EZ7g_j5_aujmdLQ0n1cS3qSiJfy7llQe1lZ99WARehnxOhKXJ0UGWIxo_gLrVeoiJ4NBufwLTssTQAKMuu2GQrO7MC2rBkdZP-tyZEhBI_nsTEin6fkNEBbOc2PsgGhTpKPuvoJcdjpQqHz_Rk-87skd2uw',
#     'width': 1500}],
#   'place_id': 'ChIJl6gPqjS7MioRg537vRedN5o',
#   'plus_code': {'compound_code': '2VG2+QW South Perth WA, Australia',
#    'global_code': '4PWQ2VG2+QW'},
# ...

# %%
next_bottle_shop_url = f'{next_bottle_shop_url}'
kc_bottle_shops_2 = requests.get(next_bottle_shop_url).json()
print(next_bottle_shop_url)
kc_bottle_shops_2
result_2 = kc_bottle_shops_2['results']
result_2
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9505,115.8605&radius=3000&type=liquor_store&pagetoken=CrQCIQEAAHxfLSIOQSEgjfkVGsfW2eMJDJT9bX5vNWIwQvMjTMqOC48E502oMzNfn7xNbPuhOzZVIZiRyb3qMVyBYyM5dWuxD3vq6Mus2Kl2QV8DZTim7voJzTSifKlfJlZArvGgvw4f4iZk8EfuhgsG5Htapzi5PjRQznlODIvu22QFxQK8CGyngzxmPTGDfp9lSRImXD7XC2Nt_CiqO8UFOuP-l5ey9Zx_-rlD8g97p5vcqd5Zjej8V3bjxLwRXlymD5XFEnM1-lVCkcpc_mAGN16Ox53lywCrEdgx0YEcIMEhD4uuxsTa_HwCnAx6DzV0soLFyIeZYTgElGmCDonUiXDOp91YCPZaX_Ukh_uqKMbM9UQwYP-e6ZARkPb4SLTKk86HKPGQj2q_jopfTCqxMzM8N50SENw1sf39_CMSo20CaszmPCEaFG_mnTuiot8vews9PeZ2Hz1Z9Yte
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.9408823, 'lng': 115.8335945},
#    'viewport': {'northeast': {'lat': -31.9394499697085,
#      'lng': 115.8349426302915},
#     'southwest': {'lat': -31.9421479302915, 'lng': 115.8322446697085}}},
# ...

# %%
next_bottle_shop_url = init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops_2['next_page_token'])
print(next_bottle_shop_url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9505,115.8605&radius=3000&type=liquor_store&pagetoken=CtQDwQEAAGo3h3wZV134e6fGA7HKH08aNiuPEORFubK2RNtjAMoKhwfTKysNGvJ3lOLEXauJkKi8Ik87im_Q4--c7WlLORsBNd71m30mdFKxmtc_1IGnUGIiTO6Rbk7j_vKwPpFvsfa7r0Q4Cs48QBZRKmE4L5cfMpRY0WUuj-KBdC34YKs3j0-o5eHH423RuN_QEiFH1IuWbzudntN-iUmWAapfZnB0pWkgXpfBVfC2h5Rj1_soqDi7_Zz9-xhGRsUgerPszTg2Uss8XE893NZLBsTAtBxAgyjQfG99zAw4FPR3hSkN54HnM4vBfCC-p1YpFA9dX54RnUe7nqMBN8kDro6978J55xanTNPMFFkeTqAjSdMwvaSCcsjqIDbgX_MxOp6XJXSX4qkxVpR_CB58BBemKAoneP6XsN6Agt5LxFfqatQ1v5InO52tuNC8oom8S9gmcfcHP61aDV3APGUdS5a08bg8Q0uA-6iHzxzZNY9tYe_N7EAqO3fDHmveUB4jWh6znsLa1wcarEGkuozPdQrLCAbkyt4Ckq5YsIRrIG2GUdKcJIFHfXKnxANYiCOAKP4lYBiMNmWANQB4Lx433rWE7BeQT_lSvRM1LkQZ1Zk2acBzEhAxZ9kOFeQwDyAgZvPp32_QGhSCNOwrTRZeHWtpj2lKPwpI-yFAVw

# %%
kc_bottle_shops_3 = requests.get(next_bottle_shop_url).json()
result_3 = kc_bottle_shops_3['results']
result_3
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.951166, 'lng': 115.840673},
#    'viewport': {'northeast': {'lat': -31.9498615197085,
#      'lng': 115.8421712802915},
#     'southwest': {'lat': -31.95255948029149, 'lng': 115.8394733197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'name': 'Kailis Wines',
#   'place_id': 'ChIJMQ9whi-lMioR9r7RIuUWLxk',
#   'plus_code': {'compound_code': '2RXR+G7 West Perth WA, Australia',
#    'global_code': '4PWQ2RXR+G7'},
#   'rating': 3,
#   'reference': 'ChIJMQ9whi-lMioR9r7RIuUWLxk',
#   'scope': 'GOOGLE',
#   'types': ['liquor_store',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': '19 Colin Street, West Perth'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.94229, 'lng': 115.8417},
#    'viewport': {'northeast': {'lat': -31.9409454197085,
# ...

# %%
kc_bottle_shops_3 = requests.get(next_bottle_shop_url).json()
print(kc_bottle_shops_3)
result_3 = kc_bottle_shops_3['results']
name3 =  [d['name'] for d in result_3]
name3
# Out:
# {'html_attributions': [], 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -31.951166, 'lng': 115.840673}, 'viewport': {'northeast': {'lat': -31.9498615197085, 'lng': 115.8421712802915}, 'southwest': {'lat': -31.95255948029149, 'lng': 115.8394733197085}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png', 'name': 'Kailis Wines', 'place_id': 'ChIJMQ9whi-lMioR9r7RIuUWLxk', 'plus_code': {'compound_code': '2RXR+G7 West Perth WA, Australia', 'global_code': '4PWQ2RXR+G7'}, 'rating': 3, 'reference': 'ChIJMQ9whi-lMioR9r7RIuUWLxk', 'scope': 'GOOGLE', 'types': ['liquor_store', 'food', 'point_of_interest', 'store', 'establishment'], 'user_ratings_total': 1, 'vicinity': '19 Colin Street, West Perth'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -31.94229, 'lng': 115.8417}, 'viewport': {'northeast': {'lat': -31.9409454197085, 'lng': 115.8429206802915}, 'southwest': {'lat': -31.9436433802915, 'lng': 115.840
# ...

# %%
# loading the data into mongodatabase

import pymongo
from pymongo import MongoClient

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Declare the database
db = client.project_2_db

# Declare the collection
bottle_shops = client.project_2_db

bars_perth = client.project_2_db

night_clubs_perth = client.project_2_db

night_clubs = client.project_2_db

# %%
# for result in result_1:
#     db.bottle_shops.insert_one(result)

# %%
# for result in result_2:
#     db.bottle_shops.insert_one(result)

# %%
# for result in result_3:
#     db.bottle_shops.insert_one(result)

# %%
# music venues data


# for x in range(2):
init_bars_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9436,115.8538&radius=3000&type=bar"

nor_bars = requests.get(init_bars_url).json()

for bars in nor_bars:
#             print(kc_bottle_shops)
#             print('--------------------------------------')
#             print(kc_bottle_shops['next_page_token'])
            next_bars_url = init_bars_url + ( "&pagetoken=" + nor_bars['next_page_token'])
            #second page url 
#             print('--------------------------------------')
#             print(next_bottle_shop_url)
#             print('--------------------------------------')
            next_bars_url = f'{next_bars_url}'

            
# next_kc_bottle_shops = requests.get(init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])).json()
            
        
result_1_bar = nor_bars['results']
result_1_bar
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.9579372, 'lng': 115.8647079},
#    'viewport': {'northeast': {'lat': -31.9563913197085,
#      'lng': 115.8661583302915},
#     'southwest': {'lat': -31.9590892802915, 'lng': 115.8634603697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Duxton Hotel Perth',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105473410416889072970">Duxton Hotel Perth</a>'],
#     'photo_reference': 'CmRaAAAAaUuf7Qs5U7tQKoLO1DY6BC9d8CD6ObZOj6cwk4DybsffgXXujvDnH0spd8y2gP417scG-7QEEneFfGjKG6gWiT_Sl87Z9SIOtmJDTEivDJLQKvdBdx6QdzfWwk0kg65eEhBtOjIm4xL-F1KoUTMARhcQGhT-x6LDG7Aa7Wg0tdaAGaAFixpeww',
#     'width': 2048}],
#   'place_id': 'ChIJX_09MCa7MioRDV3ixi9fX-A',
#   'plus_code': {'compound_code': '2VR7+RV Perth WA, Australia',
#    'global_code': '4PWQ2VR7+RV'},
# ...

# %%
next_bars_url = f'{next_bars_url}'
nor_bars_2 = requests.get(next_bars_url).json()
print(next_bars_url)
nor_bars_2
result_2_bar = nor_bars_2['results']
result_2_bar
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9436,115.8538&radius=3000&type=bar&pagetoken=CqQCGAEAAFIRyp4mafyKDdTEzV_v0JUYCB9lJi3OVBqgzU1Ly_5fIu9T78V7ikWyAMfjItWjSRk7vPKbxdrc1lFz_wmJwjCj8Wn5ZarBYAHOrYxdcaK5awpd8eT9YBQ2T5T2EOFIX9xVwh_YnEjDGVyLNB5CuPYCQ7PLVQEkjs4xylo3BhXhMIWyNv4deCFuWwwnLZQcU1dM0k2--AwbEG0f2svJw_1WqBB4ViSlpqOv7dxNh-2M9R59i4DB1xK6xNl5DrQyzZT4DRj-QfQ9Gi6vx9mr_v4lE6XbK_qYXL_BgB1Qot4dsKVB0n9XT53DNTSQrPemJdRLFeXHShFVfRBfRlx2NTKUujQSAKFECOjeiEFRFWAEph-wuYC1EqbEMfTkYn7ynBIQRtyjS2RyCYBiMDec52QptxoUyfE74WSCuOWNd8St5NEKcnsFf34
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.9575, 'lng': 115.8683333},
#    'viewport': {'northeast': {'lat': -31.95604661970849,
#      'lng': 115.8697293302915},
#     'southwest': {'lat': -31.95874458029149, 'lng': 115.8670313697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
# ...

# %%
next_bars_url = init_bars_url + ( "&pagetoken=" + nor_bars_2['next_page_token'])
print(next_bars_url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9436,115.8538&radius=3000&type=bar&pagetoken=CsQDuAEAAPLKin6PR-ugv81qbKVtAMT31YbBaqyCPNDAD7m4NwCqeKVADhq4pRTW4OVNZhtxV59SHVCgoIveTY1LovOQv00AnywTlr_xDeg6sc8yNgftI9Kfp-acOQlUDY9nsgh3CjuhVyDmxYZV3ldOT-b2I_wJnNX5OCCKdlaHXO6gGn-7vlWk5rCmDLzPJhQ8yLvwPj1SJ1BlNWwVLm5VBjOij8xM0_6nf6mfltS0dIzI5IRma2g69hZcqkmZBJbtWac-LqJXFmG_uTbXB0WiFbI6o0O9DJobPONjEmGnLkDuWZ-lU4yHN-A4wDBNSocFhT4ZysdtLmm08Kgcr2o-ylADUx2vhirREMZcj8LfdxGnRYOGu1m6qjnvQ0rCwvPGVoabMEd2S_a7MoeEKLck_zNBHgBdAoPkSjnQ9cy5n8Hdlo4NOMyS6pS5RbdIfgb9vKTQRwwgwKx8gRZNoHcokkQUQwTJshxSGOn6kbrnNp-bKpc40-4gEaShKICt4lZTyKDUjjkmC8dJUICmZQbEOO_r2cF-9iJNn1V-cOPosSKzBouFMVIg3s10sKaUOGXWqgymH163lN8JOTW1p19JQVrDOS0SEL8glvVwCc6n4fHXGZM7k9saFIXNtaFucF38GdFlQ7LPTSAgKpAG

# %%
next_bars_url = f'{next_bars_url}'
nor_bars_3 = requests.get(next_bars_url).json()
print(next_bars_url)
nor_bars_3
result_3_bar = nor_bars_3['results']
result_3_bar
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9436,115.8538&radius=3000&type=bar&pagetoken=CsQDuAEAAPLKin6PR-ugv81qbKVtAMT31YbBaqyCPNDAD7m4NwCqeKVADhq4pRTW4OVNZhtxV59SHVCgoIveTY1LovOQv00AnywTlr_xDeg6sc8yNgftI9Kfp-acOQlUDY9nsgh3CjuhVyDmxYZV3ldOT-b2I_wJnNX5OCCKdlaHXO6gGn-7vlWk5rCmDLzPJhQ8yLvwPj1SJ1BlNWwVLm5VBjOij8xM0_6nf6mfltS0dIzI5IRma2g69hZcqkmZBJbtWac-LqJXFmG_uTbXB0WiFbI6o0O9DJobPONjEmGnLkDuWZ-lU4yHN-A4wDBNSocFhT4ZysdtLmm08Kgcr2o-ylADUx2vhirREMZcj8LfdxGnRYOGu1m6qjnvQ0rCwvPGVoabMEd2S_a7MoeEKLck_zNBHgBdAoPkSjnQ9cy5n8Hdlo4NOMyS6pS5RbdIfgb9vKTQRwwgwKx8gRZNoHcokkQUQwTJshxSGOn6kbrnNp-bKpc40-4gEaShKICt4lZTyKDUjjkmC8dJUICmZQbEOO_r2cF-9iJNn1V-cOPosSKzBouFMVIg3s10sKaUOGXWqgymH163lN8JOTW1p19JQVrDOS0SEL8glvVwCc6n4fHXGZM7k9saFIXNtaFucF38GdFlQ7LPTSAgKpAG
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.9474455, 'lng': 115.8403318},
#    'viewport': {'northeast': {'lat': -31.9460521697085,
# ...

# %%
for result in result_1_bar:
    db.bars_perth.insert_one(result)

# %%
for result in result_2_bar:
    db.bars_perth.insert_one(result)

# %%
for result in result_3_bar:
    db.bars_perth.insert_one(result)

# %%
#night clubs

# %%
# for x in range(2):
init_nc_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9436,115.8538&radius=3000&type=night_club"

nor_nc = requests.get(init_nc_url).json()

for nc in nor_nc:
#             print(kc_bottle_shops)
#             print('--------------------------------------')
#             print(kc_bottle_shops['next_page_token'])
            next_nc_url = init_nc_url + ( "&pagetoken=" + nor_nc['next_page_token'])
            #second page url 
#             print('--------------------------------------')
#             print(next_bottle_shop_url)
#             print('--------------------------------------')
            next_nc_url = f'{next_nc_url}'

            
# next_kc_bottle_shops = requests.get(init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])).json()
            
        
result_1_nc = nor_nc['results']
result_1_nc
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.9502778, 'lng': 115.8625},
#    'viewport': {'northeast': {'lat': -31.9488897197085,
#      'lng': 115.8637158302915},
#     'southwest': {'lat': -31.9515876802915, 'lng': 115.8610178697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'name': 'The Court',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2848,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117536139284191548789">The Court</a>'],
#     'photo_reference': 'CmRaAAAAVcyQgxGPgcc_EH_kl8sa6BTRqkBRTtkPDd_xgLpFKDz2L86m-rj9v0YMLkdkwvULc1EArZuMA3U-H6DTP9__9EgMCGFv8nZbpm3Y9QN4ArnlmdWPvbS4Yd2SlrUDp1AaEhCTQJ3iBLUfDBe3WoE9eD7LGhSQtT8XPTRKSGEP4y0EFz1tZjNFYA',
#     'width': 4288}],
#   'place_id': 'ChIJt-v5N9e6MioR1Nh-mPvJkMM',
#   'plus_code': {'compound_code': '2VX7+V2 Perth WA, Australia',
#    'global_code': '4PWQ2VX7+V2'},
#   'price_level': 2,
# ...

# %%
next_nc_url = f'{next_nc_url}'
nor_nc_2 = requests.get(next_nc_url).json()
print(next_nc_url)
nor_nc_2
result_2_nc = nor_nc_2['results']
result_2_nc
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9436,115.8538&radius=3000&type=night_club&pagetoken=CqQCHwEAAPy5Z260t440TyuCUiU6XfFE62auQuisC2MCuOIc7usr9PN2yVaXeV0K_mJcjdVlnEKsT_6QQI4yYhAMHTYFPMiG3iy6m4025NGJlKqlKg4h56xE5BOucpWXORH1lyyVQgE253OpKPZostZ4FqoQfz0BmY5R6BTXlXSLXN-Fj2oHHfTxn0HoY0HT23jZEnxj4DFpT3Eav7Rf07QQ3qhpuRrQUwPtMzQN2N6OByh3a97SdETLSlsi6OtCvfOnpI3rX5MQr6v5QEuPs2KJf6-fxdFu8HLSZuTwdRK-UX43oVKYsO0I8ZxqPX1lI7rY8gTBQkSc4evYGcWc1BEJm7FtH3lCwo4sxi0lm51GukSL8UnJrSrANits2kevc7ifBrrCjhIQi4EJLZlQ9AzLF40EqIcJGBoUBPhUW4kLAn5W8ZV64eaxEWHCk9o
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.9383503, 'lng': 115.8420907},
#    'viewport': {'northeast': {'lat': -31.9369794197085,
#      'lng': 115.8433890302915},
#     'southwest': {'lat': -31.9396773802915, 'lng': 115.8406910697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
# ...

# %%
next_nc_url = init_nc_url + ( "&pagetoken=" + nor_nc_2['next_page_token'])
print(next_nc_url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9436,115.8538&radius=3000&type=night_club&pagetoken=CsQDvwEAAO3niI7_lBaBHmKSCsWxz7lZPuCYw6n7lb12B4I0AVr9b-6EJ_QRjPifcZMI3u2O5PAXF_zZ8ZlQdpE_XDMtWkkOu-nC9ZfPCKXmRNOwqjYCT_6iNB0-IDPjCXUtqOzEUxZ_tGvcpCPhvGCR29yFiK_F9kFSyr8SGanrpn4rYU5qLJs4AawTBT4HnJqq1lEch8CAfSxn61Q1_-jnbbstpZbEaFSC_I9ZzwjyZlt_TZtB_0NOVRcx2Te7JlYUEpw0gEJ7xO7y5LY_zsUS5fkCn4qVB1XLPcOLOlWntSyk5Se-esweYSjVoqQ9Go282v6F5QkNJ5jRrwkG6cXZm3wo3jbDgdYRI1Wn-Ofqflw2NLarj4HjihzEYKN77kCzbJHRWT1pjM3jshnnKl_qvfpgX5vCW3mssjI8e7NEtrTnycQcKqeWwFYQE8SgtYH1bb7GQvVYKQQnv0PpRHro0Gkn3EAGGP_28Ao_rERr8xcgEWwb0g6ulf0go2kD1NWVy-FVcNcOvVVXAbpJGOzxjux0Kak50J0fACasuk7QbuOh10pbvln1ONTbbcSE2_cDZP0P33QNoznVQvoDWj4VvoQ0sxESEHzQ8JjZHdY9UfDaU3MFtTIaFJKKkiWWY0w4xzJ7Sb5alqGxDHa9

# %%
next_nc_url = f'{next_nc_url}'
nor_nc_3 = requests.get(next_nc_url).json()
print(next_nc_url)
nor_nc_3
result_3_nc = nor_nc_3['results']
result_3_nc
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-31.9436,115.8538&radius=3000&type=night_club&pagetoken=CsQDvwEAAO3niI7_lBaBHmKSCsWxz7lZPuCYw6n7lb12B4I0AVr9b-6EJ_QRjPifcZMI3u2O5PAXF_zZ8ZlQdpE_XDMtWkkOu-nC9ZfPCKXmRNOwqjYCT_6iNB0-IDPjCXUtqOzEUxZ_tGvcpCPhvGCR29yFiK_F9kFSyr8SGanrpn4rYU5qLJs4AawTBT4HnJqq1lEch8CAfSxn61Q1_-jnbbstpZbEaFSC_I9ZzwjyZlt_TZtB_0NOVRcx2Te7JlYUEpw0gEJ7xO7y5LY_zsUS5fkCn4qVB1XLPcOLOlWntSyk5Se-esweYSjVoqQ9Go282v6F5QkNJ5jRrwkG6cXZm3wo3jbDgdYRI1Wn-Ofqflw2NLarj4HjihzEYKN77kCzbJHRWT1pjM3jshnnKl_qvfpgX5vCW3mssjI8e7NEtrTnycQcKqeWwFYQE8SgtYH1bb7GQvVYKQQnv0PpRHro0Gkn3EAGGP_28Ao_rERr8xcgEWwb0g6ulf0go2kD1NWVy-FVcNcOvVVXAbpJGOzxjux0Kak50J0fACasuk7QbuOh10pbvln1ONTbbcSE2_cDZP0P33QNoznVQvoDWj4VvoQ0sxESEHzQ8JjZHdY9UfDaU3MFtTIaFJKKkiWWY0w4xzJ7Sb5alqGxDHa9
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -31.9597526, 'lng': 115.8723538},
#    'viewport': {'northeast': {'lat': -31.9584856197085,
# ...

# %%
for result in result_1_nc:
    db.night_clubs_perth.insert_one(result)

# %%
for result in result_2_nc:
    db.night_clubs_perth.insert_one(result)

# %%
for result in result_3_nc:
    db.night_clubs_perth.insert_one(result)

# %%
night_clubs = client.project_2_db
