# %%
# Dependencies
import requests
import pandas as pd

url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=3000&type=liquor_store&pagetoken=CrQCIQEAAKVSWrz5Z4PWgTGVSuKUDZEy5_Jf0GHNY6rkAaw4WqKKqvDR6LHJWiEMpqEKKD-BJeAl5UPyjGhSdfBQCDQbF5nbXcq45lX2h8KyYnR77yohrowzbPj77H7raATvQPnebxneczD0pbCn0xjBvzMmQ_TAVV7zVR0cw317lAtN1Yq8UIttCksCcmtYhBHwTfMTqZ70r0QyqshxlW4AP1bRN5-2MBQtMl6KymMa8SNzISAdsJFVPPF4fdRU3OjxhGj6yBFaxc0xwoypW1UJGqO7kHSdcccWNt2qymEu1xWq-rG3UOxfUEbQAJB3UIx5JBBRaK0ndFkO3JFJtwrVvxkrWFbc5bKa7Uoi7E6cep4FF9BAuTSWQCeqeFLNBgw4KqwqyJNCplmtQF4aAaqiHjqlDCsSEH6hI5qLINLGHvAU__3vS0QaFCllHh2KJLOKOJmN-gPM6ZyRhLXD"

# %%
bottle_shop = requests.get(url).json()

for x in bottle_shop:
    print(bottle_shop)
# Out:
# {'html_attributions': [], 'next_page_token': 'CtQDwQEAADX5aE4vUOh4CWc1VzWSAyIpJHTczC5-0CkuB7uJmmkVOTGsa2_nt4bscR77-lbBWdBZaNeEAwtmdc0hXFiyCLt_OUWUmxckA89qAR9y2ASWxNypESp2kYRDRPxK7hGUZ-QiV3NwZp0KzMDw83zCMoeLiLhyqhYZe9FrbefC8ccUC_IVU7L1slTx1u4IXyV9UvHz3KmCXIxbJdFyh5Rx3ESqAQ0WLxGn4RrsrO8TT-7-_n9pGDQ-4TyXR9gOexCxEfsI4eqNTpf8KSWOYi5zcU3O9OtDDThzoFCgvSu1SVqPz48AG6PkW_06V6yrBwc_08NpshLTwHTliuu5J8oGZRuhB9nTkTFSJRx9V08UEhBx3lZb79pZluO9mJDmmrbBGhTvojcJJqzywtfgt6AA1-A4LIyaWw', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -33.841749, 'lng': 151.220142}, 'viewport': {'northeast': {'lat': -33.8400677697085, 'lng': 151.2215236302915}, 'southwest': {'lat': -33.8427657302915, 'lng': 151.2188256697085}}}, 'icon'
# ...

# %%
bottle_shop
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CtQDwQEAADX5aE4vUOh4CWc1VzWSAyIpJHTczC5-0CkuB7uJmmkVOTGsa2_nt4bscR77-lbBWdBZaNeEAwtmdc0hXFiyCLt_OUWUmxckA89qAR9y2ASWxNypESp2kYRDRPxK7hGUZ-QiV3NwZp0KzMDw83zCMoeLiLhyqhYZe9FrbefC8ccUC_IVU7L1slTx1u4IXyV9UvHz3KmCXIxbJdFyh5Rx3ESqAQ0WLxGn4RrsrO8TT-7-_n9pGDQ-4TyXR9gOexCxEfsI4eqNTpf8KSWOYi5zcU3O9OtDDThzoFCgvSu1SVqPz48AG6PkW_06V6yrBwc_08NpshLTwHTliuu5J8oGZRuhB9nTkTFSJRx9V08UEhBx3lZb79pZluO9mJDmmrbBGhTvojcJJqzywtfgt6AA1-A4LIyaWw',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -33.841749, 'lng': 151.220142},
#     'viewport': {'northeast': {'lat': -33.8400677697085,
#       'lng': 151.2215236302915},
# ...

# %%
list_bottleshops = bottle_shop['results']

# %%
list_bottleshops  = bottle_shop["results"]
list_bottleshops
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -33.841749, 'lng': 151.220142},
#    'viewport': {'northeast': {'lat': -33.8400677697085,
#      'lng': 151.2215236302915},
#     'southwest': {'lat': -33.8427657302915, 'lng': 151.2188256697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'name': 'The Vine Press',
#   'opening_hours': {'open_now': True},
#   'place_id': 'ChIJZ_Upc5CuEmsR_m-Ck3umoOM',
#   'plus_code': {'compound_code': '565C+83 Neutral Bay NSW, Australia',
#    'global_code': '4RRH565C+83'},
#   'rating': 4.2,
#   'reference': 'ChIJZ_Upc5CuEmsR_m-Ck3umoOM',
#   'scope': 'GOOGLE',
#   'types': ['liquor_store',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 5,
#   'vicinity': '11 Lower Wycombe Road, Neutral Bay'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -33.8797414, 'lng': 151.2162025},
# ...

# %%
# types =  [d['types'] for d in list_bottleshops]
# types

# %%
# name =  [d['name'] for d in list_bottleshops]
# name

# %%
# geometry = [d['geometry'] for d in list_bottleshops]
# location = [d['location'] for d in geometry]
# location

# %%
# vicinity =  [d['vicinity'] for d in list_bottleshops]
# vicinity

# %%
# df = pd.DataFrame(name,columns =['Bottle_Shop_Name'])
# df['Address']= vicinity
# df['Types'] = types
# df['Coordinates'] = location
# google_place_api_bottle_list = df
# google_place_api_bottle_list

# %%
# loading the data into mongodatabase

import pymongo
from pymongo import MongoClient

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Declare the database
db = client.project_2_db

# Declare the collection
bottleO = client.project_2_db

# %%
for result in list_bottleshops:
    db.botttleO.insert_one(result)

# %%
# bottle_shop_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=liquor_store"
# kc_bottle_shops = requests.get(bottle_shop_url).json()

# print(sydney_bottle_shops['next_page_token'])

# for x in range(2):
init_bottle_shop_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=liquor_store"

kc_bottle_shops = requests.get(init_bottle_shop_url).json()

for bottle_shop in kc_bottle_shops:
#             print(kc_bottle_shops)
#             print('--------------------------------------')
#             print(kc_bottle_shops['next_page_token'])
            next_bottle_shop_url = init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])
            #second page url 
#             print('--------------------------------------')
#             print(next_bottle_shop_url)
#             print('--------------------------------------')
            next_bottle_shop_url = f'{next_bottle_shop_url}'

            
# next_kc_bottle_shops = requests.get(init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])).json()
            
        
result_1 = kc_bottle_shops['results']
result_1
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -33.8713517, 'lng': 151.1947299},
#    'viewport': {'northeast': {'lat': -33.8699477697085,
#      'lng': 151.1961274302915},
#     'southwest': {'lat': -33.8726457302915, 'lng': 151.1934294697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'The Dunkirk Hotel',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3180,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100619007458021702675">The Dunkirk Hotel</a>'],
#     'photo_reference': 'CmRaAAAASo4W8zvQjsGSf6-0AV3AnmaS-FiOf3E_9splky5wcTsgUegZ4OuXl6qWTheOYWQIaRH_WNcxQdJiD4olKQ9djIse7cSFCIlWKIl-8Ty-SHysHWX4OgI3zTmG00-5XOCnEhB64JH8Ym1wZSCzDQNVccXzGhSaXW_4Cy3AzQLiRTJadu2DMNY80A',
#     'width': 4770}],
#   'place_id': 'ChIJ4UEnPTGuEmsRkjpDW7FRSko',
#   'plus_code': {'compound_code': '45HV+FV Pyrmont NSW, Australia',
#    'global_code': '4RRH45HV+FV'},
# ...

# %%
# next_bottle_shop_url = f'{next_bottle_shop_url}'
# kc_bottle_shops_2 = requests.get(next_bottle_shop_url).json()
# print(next_bottle_shop_url)
# kc_bottle_shops_2
# result_2 = kc_bottle_shops_2['results']
# result_2
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=liquor_store&pagetoken=CrQCIQEAAHgJIt2uYRUZ5OEMljpjNi540e7rf7eL3J4eu2zGYlpJ0LnD_Cnx1uSdu0sFrd0fT2N5wLcKC8rZIBgShhZP0naPw8O6y1nePnb1l_C5TbMQYjr6VafPL8G9HLWJwCWWPpTMOZowuUVi5dSWpmoU84RRHGjf3U4NF9DDFO62q9HbBxr4ONdmnkf1ZiTq6bpFZQ6_sOoqZW_WbRvnLZMj4ZZtNIQ5DomOH6O5wEWL-svimpT2eo1Eaz3np60dtP-L4xQhd4OAU4YG8a5dL59P8U5fh4fS7C6R7kqTMCmZe3pLLLRTjJFLaenZtvT5VSPB0FPqgZx_9kJuzu3j4Sz_iZ_kQYBDQewcm_taUICmaflQ-ISOOjmAJeVISdWrgMTTwvhirMgotEm9XUqKpL2PDaQSEK_oc_qJNMNzkxp_h2SY4UoaFH1VMo9pu3WGSVl04YIA0P5LcIH4
# []

# %%
# next_bottle_shop_url = init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops_2['next_page_token'])
# print(next_bottle_shop_url)

# %%
kc_bottle_shops_3 = requests.get(next_bottle_shop_url).json()
result_3 = kc_bottle_shops_3['results']
result_3
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -33.8820869, 'lng': 151.2754471},
#    'viewport': {'northeast': {'lat': -33.8807543697085,
#      'lng': 151.2769228802915},
#     'southwest': {'lat': -33.8834523302915, 'lng': 151.2742249197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'name': 'Vintage Cellars Bondi',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102195916077572779389">Tony Gallagher</a>'],
#     'photo_reference': 'CmRaAAAATHNdrVBe0zMWUhwR-HkZDKYxeceXYPJFDEMgxX-apiY8G3LPWLhs7_dCnfTu7SOmJ27iQMAG6sdpgOUtN71lXJ71UK92CyIqsKB_bKTj3e2-LiuulUH5LCS6RH1eEpwrEhAn23Z1yZHd6kUdLS62bdeGGhS3M19eFZBtN06LCZqr8K6UB1jySA',
#     'width': 4032}],
#   'place_id': 'ChIJ4RVpf_GtEmsRDBd1bi_HfSA',
#   'plus_code': {'compound_code': '479G+55 North Bondi NSW, Australia',
#    'global_code': '4RRH479G+55'},
# ...

# %%
kc_bottle_shops_3 = requests.get(next_bottle_shop_url).json()
print(kc_bottle_shops_3)
result_3 = kc_bottle_shops_3['results']
name3 =  [d['name'] for d in result_3]
name3
# Out:
# {'html_attributions': [], 'next_page_token': 'CtQDwQEAAPQNR6TxNvm4d_hM2NAOcxM2AnrRlqgBn3wpv6K0NtYc8TKf79JRHAmXJ9azUEohMcN6umxqBAIeifzSTdOFSCpOQXhNLQg0zvskBX0Ucx8iVoCIZJ4C9fTiMVA7xW8ip2GYaSvdbGNe928vymq5aUUQOKCRaBL3qojjgQhVhC_SuiCBdk1NDOJI0G1ct_Ch2aDPOv9ygQCP7OD0ww80DGOmdXUkhBUeCv2YCxzNlin-5cfaa2BREY0O0HVfkpZE392UohWXiocdWqenwlfTeHXhWFMcenTXmaeaAxblElfQXaOEXn0Fp8NJ3WMy0h3LiZr4WNhdEvU2qGybnEE9rIJuqls6bAHqakf96NRVwtCfbyWxWaBriLrPHcjwmMGYCXCt-EmZftm1kaZq_b-pW7VWL2dBFXhUwOGDgMEntA4BgyLjdUNNWA4Aheeda9nKVfsCI05AqNph4m-fkKq4GWaxxzKrHR6wg1mhJMY1ibvNfaImtgj23fkzeP19OjlyPA4kq6w_-wkqNd7v92yO31lsuHyraifMtmZhdnez5MVxBh4Ua4UHNXRnLaozZnharsAYZcLVF_ccPUpCbGWwveTiQmxBjEqwURrqPGVc8rr5EhDkqbAIgxsbQT1GJ2D3cxtUGhQcyYbusc2lorU2x3aaTlByroDkoA', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': -33.8820869, 'lng': 151.2754471}, 'viewport': {'northeast': {'lat': -33.8807543697085, 'lng': 151.2769228802915}, 'southwest': {'lat': -33.8834523302915, 'lng': 151.2742249197085}}}, 'ico
# ...

# %%
# loading the data into mongodatabase

import pymongo
from pymongo import MongoClient

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Declare the database
db = client.project_2_db

# Declare the collection
sydney_bottle_shops = client.project_2_db

bottle_shops = client.project_2_db

# %%
# list_bottleshops
result_1
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -33.8713517, 'lng': 151.1947299},
#    'viewport': {'northeast': {'lat': -33.8699477697085,
#      'lng': 151.1961274302915},
#     'southwest': {'lat': -33.8726457302915, 'lng': 151.1934294697085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'The Dunkirk Hotel',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3180,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100619007458021702675">The Dunkirk Hotel</a>'],
#     'photo_reference': 'CmRaAAAASo4W8zvQjsGSf6-0AV3AnmaS-FiOf3E_9splky5wcTsgUegZ4OuXl6qWTheOYWQIaRH_WNcxQdJiD4olKQ9djIse7cSFCIlWKIl-8Ty-SHysHWX4OgI3zTmG00-5XOCnEhB64JH8Ym1wZSCzDQNVccXzGhSaXW_4Cy3AzQLiRTJadu2DMNY80A',
#     'width': 4770}],
#   'place_id': 'ChIJ4UEnPTGuEmsRkjpDW7FRSko',
#   'plus_code': {'compound_code': '45HV+FV Pyrmont NSW, Australia',
#    'global_code': '4RRH45HV+FV'},
# ...

# %%
# for result in result_1:
#     db.bottle_shops.insert_one(result)

# %%
# for result in result_2:
#     db.bottle_shops.insert_one(result)

# %%
# for result in result_3:
#     db.bottle_shops.insert_one(result)

# %%
# music venue and bar data

# %%
# bottle_shop_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=liquor_store"
# kc_bottle_shops = requests.get(bottle_shop_url).json()

# print(sydney_bottle_shops['next_page_token'])

# for x in range(2):
init_night_club_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=night_club"

kc_night_clubs = requests.get(init_night_club_url).json()

for night_clubs in kc_night_clubs:
#             print(kc_bottle_shops)
#             print('--------------------------------------')
#             print(kc_bottle_shops['next_page_token'])
            next_nightclub_url = init_night_club_url + ( "&pagetoken=" + kc_night_clubs['next_page_token'])
            #second page url 
#             print('--------------------------------------')
#             print(next_bottle_shop_url)
#             print('--------------------------------------')
            next_nightclub_url = f'{next_nightclub_url}'

            
# next_kc_bottle_shops = requests.get(init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])).json()
            
        
result_1_nc = kc_night_clubs['results']
result_1_nc
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -33.8823787, 'lng': 151.2046676},
#    'viewport': {'northeast': {'lat': -33.8810741197085,
#      'lng': 151.2059824802915},
#     'southwest': {'lat': -33.88377208029149, 'lng': 151.2032845197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Wake Up! Sydney',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1365,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113381452924465106507">Wake Up! Sydney</a>'],
#     'photo_reference': 'CmRaAAAAaoAfiFK2R6sZKLRHstVFUlJE8gT_OqUeM1OGQMPQVOgG6lRR8zYG5R50Bv36q_o7yyRJCjA9ALb6G4a6fNXGXKeWaUfCPZAETY3XnZP432De5R9zQPxXqFsZkftn8GqsEhBzE_OwfIgQ2vE9WweZncqlGhQhuLOsMeXO11fl_K_IXGO8cofNow',
#     'width': 2048}],
#   'place_id': 'ChIJ1_5Y_yOuEmsRU3ORQg0SYpg',
#   'plus_code': {'compound_code': '4693+2V Sydney NSW, Australia',
#    'global_code': '4RRH4693+2V'},
# ...

# %%
next_nightclub_url = f'{next_nightclub_url}'
kc_nc_2 = requests.get(next_nightclub_url).json()
print(next_nightclub_url)
kc_nc_2
result_2_nc = kc_nc_2['results']
result_2_nc
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=night_club&pagetoken=CqQCHwEAAEEpQ2BKri2fT4rdidOziQVKLGlkqssR6oGfIwkdQD_mOBz9t5Pc7YHpPZzEDS9djXALAtZqxRSlq7Q5opngQJsD5rbAx-Fgtvjvjc4JNgye3o-qgzaf10QWSGN393e3IB14TWV74pN4gRWWZMV07Y0ZWt3BhM6ntE8sMww8JS9danBgQkhnxSxqLCpT-IhSuNH73kUvK_jXHAPutNqYuDL2dW3Mar9yTY_P10Mf-dpwvfUk-YqT98KXfqRY8yeWUyipmQWkiPIuNGleMz3FGBslkN2AJ80y3VpplCnqgXMiV9ycDncrPK6A5o4HuD-GEGFMjPyYijm8ve47hqMTz-L4_8MdAo-ZkeE98wWVNfZOdNwC95rJ--88L6g55V2YBhIQ2-_UFtvonjS638tw4OZ_MBoU8J-GFfQQSYLA3IF-VxJ-TTLGt_8
# [{'business_status': 'CLOSED_TEMPORARILY',
#   'geometry': {'location': {'lat': -33.87787229999999, 'lng': 151.2133158},
#    'viewport': {'northeast': {'lat': -33.8764694197085,
#      'lng': 151.2147285802915},
#     'southwest': {'lat': -33.8791673802915, 'lng': 151.2120306197085}}},
# ...

# %%
next_nightclub_url = init_night_club_url + ( "&pagetoken=" + kc_nc_2['next_page_token'])
print(next_nightclub_url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=night_club&pagetoken=CsQDvwEAAM_nFZyoSCMlMyFAoLWU_cDAKWImUsUR9FKa72MRyPlks_kx8H2jzDRVyGtTjUogCKgVIXuj1uE6bZwhp5U-XbnVbSctZj6sxIKRPc8IKrf22YwV2vNjA8LHbWHIf8Wd44rdNXJeWzkuPfOsbhjyFE5LptWJTBlg1l27OaBs1yzeW_xStAhVgd8jqxouR0f-K0hVwLJl728rDhfdSpqazFD_xSP4EIXctRUB1LGgpbbhp-joCyZgVTUZSV2abxgwobQ7Csee1ReCtFlml8jMFTkz4hPZU2OQ6Y7hCj9LygpT192cd0UAbRc1uYd13lOcuifel5bEMuR8NvPzVEvju1kiz2BLw9Rj-otu1YAADx_OYMauviMmjtJsN_px6PF6VHRcWY6BZ95KORxS_9xzve9scbAjS3pbH1USTKNAg5jOGzdMMH9HU2qACWEET9O7a-3oGDnkPg08O8UKId_wwVspxXFsx5Um_lN50eO7cR7TriSFND9eRwuIy5ILiCkVld9FR8N0LI1Fhc0DqhSatCS09J_Q9KFDY5GT737jcvA1mYyh1dHI_11aUSyidTtMdJZJxAax1eZWp5tmg8VM10wSEBAVr37WDBlAtq1AlyJmDzsaFPqygQkeqErb22rK5aTJcYDC55OL

# %%
kc_nc_3 = requests.get(next_nightclub_url).json()
result_3_nc = kc_nc_3['results']
result_3_nc
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': -33.8744672, 'lng': 151.2157539},
#    'viewport': {'northeast': {'lat': -33.8729909697085,
#      'lng': 151.2171346802915},
#     'southwest': {'lat': -33.8756889302915, 'lng': 151.2144367197085}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'name': 'Club 77',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 811,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112616528338465968342">Club 77</a>'],
#     'photo_reference': 'CmRaAAAAwgE_1-djm0PfrPCPDXJC28wvnDoZaM_6UFL5OPtJrmPTUYwGMgxf_1q0-CAlG6XEyFAuDFVGcwScpbfHGUNt0B7PHVghglCzRLJcUrKjgKKMrlyMaMnMfV3uFdrbPLQNEhDUNhnWeaXBlB5WQ1lwWj7DGhRwN-UYrp4XJgPqEYkZzIkRLJSu3Q',
#     'width': 1440}],
#   'place_id': 'ChIJeX5cDBSuEmsRqQ2OyShXk_I',
#   'plus_code': {'compound_code': '46G8+68 Darlinghurst NSW, Australia',
#    'global_code': '4RRH46G8+68'},
#   'rating': 4.1,
# ...

# %%
result_3_nc = kc_nc_3['results']
name3_nc =  [d['name'] for d in result_3_nc]
name3_nc
# Out:
# ['Club 77',
#  'Reggio Lounge',
#  'The Cliff Dive',
#  'AM//PM',
#  'Candelaria - Sydney',
#  'Club Grand Hit',
#  'MVP Nightclub',
#  'Space',
#  'Diva Body Tone, Sydney Body Massage, City Erotic Massage, Surry Hills Body Massage, Central Erotic Massage',
#  'Three Bottle Man',
#  'Republic Hotel',
#  'Treasure Cove Gaming Lounge',
#  'K1 Karaoke Lounge',
#  'Dynasty Karaoke',
#  'Café del Mar Sydney',
#  'S.A.S.H',
#  'D1 Karaoke Sydney',
#  'The Mardi Gras Disco Climb - The Rocks',
#  'Red Room Sydney',
#  'HQ Living']

# %%
# loading the data into mongodatabase

import pymongo
from pymongo import MongoClient

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Declare the database
db = client.project_2_db

# Declare the collection
kings_cross_night_clubs = client.project_2_db

night_clubs_sydney = client.project_2_db

bars_sydney = client.project_2_db

# %%
for result in result_1_nc:
    db.night_clubs_sydney.insert_one(result)

# %%
for result in result_2_nc:
    db.night_clubs_sydney.insert_one(result)

# %%
for result in result_3_nc:
    db.night_clubs_sydney.insert_one(result)

# %%
#night clubs in Marrickville
# radius set 3km

# %%
# bottle_shop_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=liquor_store"
# kc_bottle_shops = requests.get(bottle_shop_url).json()

# print(sydney_bottle_shops['next_page_token'])

# for x in range(2):
init_night_club_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.9087, 151.1524&radius=3000&type=night_club"

marr_night_clubs = requests.get(init_night_club_url).json()

# for night_clubs in marr_night_clubs:
# #             print(kc_bottle_shops)
# #             print('--------------------------------------')
# #             print(kc_bottle_shops['next_page_token'])
#             next_nightclub_url = init_night_club_url + ( "&pagetoken=" + marr_night_clubs['next_page_token'])
#             #second page url 
# #             print('--------------------------------------')
# #             print(next_bottle_shop_url)
# #             print('--------------------------------------')
#             next_nightclub_url = f'{next_nightclub_url}'

            
# next_kc_bottle_shops = requests.get(init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])).json()
            
        
result_1_nc_marr = marr_night_clubs['results']
# result_1_nc_marr

name_nc_marr =  [d['name'] for d in result_1_nc_marr]
name_nc_marr
# Out:
# ['CHiLLi PiP - Custom made lounges in Sydney.',
#  'Black Express Light and Sound',
#  'Nortons On Norton',
#  'Riverview Pinup Pub Tempe',
#  'Holey Moley Golf Club Newtown',
#  'Cafe Claire',
#  'Elegant Interior 1',
#  'The Imperial Erskineville',
#  'Pablito’s Milonga',
#  'Luvstuff Adult Shop',
#  'The Marrickvilla',
#  "Ruby's Dance Hall",
#  'Jangos',
#  'Slime House',
#  'Bedford St Tunnel',
#  'Coiaba Crew’s house']

# %%
for result in result_1_nc_marr:
    db.night_clubs.insert_one(result)

# %%
# bars in marrickville

# %%
init_bars_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.9087,151.1524&radius=3000&type=bar"

marr_bars = requests.get(init_bars_url).json()

for bars in marr_bars:
#             print(kc_bottle_shops)
#             print('--------------------------------------')
#             print(kc_bottle_shops['next_page_token'])
            next_marr_bars_url = init_bars_url + ( "&pagetoken=" + marr_bars['next_page_token'])
            #second page url 
#             print('--------------------------------------')
#             print(next_bottle_shop_url)
#             print('--------------------------------------')
            next_marr_bars_url = f'{next_marr_bars_url}'

            
# next_kc_bottle_shops = requests.get(init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])).json()
            
        
result_1_bar_marr = marr_bars['results']
# result_1_nc_marr

name_bars_marr =  [d['name'] for d in result_1_bar_marr]
name_bars_marr
# Out:
# ["Delhi 'O' Delhi",
#  'Bloodwood Restaurant & Bar',
#  'Palace Norton Street',
#  'Websters Bar',
#  'The Vic On The Park',
#  'The Henson',
#  'The Bank',
#  'Courthouse Hotel',
#  'Camelot Lounge',
#  'CHiLLi PiP - Custom made lounges in Sydney.',
#  'The Duke of Enmore',
#  'Hartsyard',
#  'Royal Exchange Hotel',
#  'Andiamo Trattoria Summer Hill',
#  'Nortons On Norton',
#  'Arabella Lebanese Restaurant',
#  'Union Hotel',
#  'Town Hall Hotel',
#  'Botany View Hotel',
#  'Rowers On Cooks River']

# %%
next_marr_bars_url = f'{next_marr_bars_url}'
marr_bars_2 = requests.get(next_marr_bars_url).json()
print(next_marr_bars_url)
# marr_bars_2

result_2_bars_marr = marr_bars_2['results']
result_2_bars_marr

name_bars_marr_2 =  [d['name'] for d in result_2_bars_marr]
name_bars_marr_2
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.9087,151.1524&radius=3000&type=bar&pagetoken=CqQCGAEAABnInlVVNfUvrr4N4wlQkcAL3uE1W5gIPZU6THoEnJau7_QzFgKbTVtrhI_V6KgSwIY18ygGBN8f4O9FIzRC7IuR0FCqojPpWQR5pvugaFRyK3v84AdinDZIezaqNVG__5J6DjkturdbDOxEAX4bFKpT096kOE0m3-Ub0baYeiWmGjWA2IQ4LSuHUwQhtUmavwOIJ2DCDPvfGUVfy3ywGz54pfoZRfemYbyih04nXZlLet8CRejsv_JX9dvHweSvetu8Vptg_Jgwf8svfMXUEmlGXfKR6St8hklmwilQ0tdNkdG3Zlhx8dvyDtunhv97ENs4EukZjo8KeCU8DRr1s2gIciROTGFhyIHaGo4U4g5MTAol33t8jihiLf3ONgMAlBIQ6dPh06unoZ00xVcaKKTeEhoUuwlfbExQmqnZOWVbIsMVDbDq3MQ
# ['Hurlstone Park Hotel',
#  'Portugal Madeira Club',
#  'Marrickville Ritz Hotel',
#  'Bucket Boys Craft Beer Co',
#  'Titus Jones',
#  'Gasoline Pony',
#  'The Sausage Factory',
#  'White Cockatoo Hotel',
#  'MANIAX Axe Throwing - SYDNEY',
#  'Riverview Pinup Pub Tempe',
#  'Town & Country Hotel',
#  'Zebra Bar',
#  'Oscars Grill',
#  'Jacoby’s Tiki Bar',
#  'Stanbuli',
# ...

# %%
next_marr_bars_url = init_bars_url + ( "&pagetoken=" + marr_bars_2['next_page_token'])
print(next_marr_bars_url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.9087,151.1524&radius=3000&type=bar&pagetoken=CsQDuAEAAFqtjivdGi_iYN8zTdGsqNXquhnUDbMou668L-wCxgklTOmalwLmcAzHiBDdRvI05qu6hvZB8njWf5QLFgulzo_tXS4AzN7cOnrJJXdUvIH0plz2FqEJM60TIRwa5j13bNJ7w4pNWIX6PnIxeUPmhUexKfHfMehEWPvD5K3ykSHRv20YIc8EF9_5v2eNVTzqoTsv5btoU_TQReON3cECspD16um_U2lXPJo0GhiuZS_X4X9mQ4OsCWEYqbCM_l7zxQeG699quT2uSVVhcVVvgKTfev6T088b1v6RpxInK0nnGRaMFsDhAAPYxmmjU8OMt71r_06Y3KuViQp2gcTWnZURsO_5idxsxpJh9n-B7sr0i0Ihn6upP5POKxLOFex_Qyld6Zq1Z94WGv7Rmos4Ip_TZ-v8QjLl5cyhbfpOk-QjPvI8SOgPsgB5PESfrSTcIGTgGWjs13ow6dL-p82AeZwyUBI3dHcQt4pi1t33bufEm-QQX9PGeaNSyeEdYfVDHXsL6AKLGRsOGnoD0lYH2miDwuK5KcTXL9olLVe9Bqrej8q2rAs6FWCw0VAH0yBOlVsT1NaxPhE_uTp0ae9mEvESEAdYhImLA9KNcPx1YII8A2QaFBzKzu-_5q138tAmgk4Elwy43aru

# %%
next_marr_bars_url = f'{next_marr_bars_url}'
marr_bars_3 = requests.get(next_marr_bars_url).json()
print(next_marr_bars_url)
# marr_bars_2

result_3_bars_marr = marr_bars_3['results']
result_3_bars_marr

name_bars_marr_3 =  [d['name'] for d in result_3_bars_marr]
name_bars_marr_3
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.9087,151.1524&radius=3000&type=bar&pagetoken=CsQDuAEAAFqtjivdGi_iYN8zTdGsqNXquhnUDbMou668L-wCxgklTOmalwLmcAzHiBDdRvI05qu6hvZB8njWf5QLFgulzo_tXS4AzN7cOnrJJXdUvIH0plz2FqEJM60TIRwa5j13bNJ7w4pNWIX6PnIxeUPmhUexKfHfMehEWPvD5K3ykSHRv20YIc8EF9_5v2eNVTzqoTsv5btoU_TQReON3cECspD16um_U2lXPJo0GhiuZS_X4X9mQ4OsCWEYqbCM_l7zxQeG699quT2uSVVhcVVvgKTfev6T088b1v6RpxInK0nnGRaMFsDhAAPYxmmjU8OMt71r_06Y3KuViQp2gcTWnZURsO_5idxsxpJh9n-B7sr0i0Ihn6upP5POKxLOFex_Qyld6Zq1Z94WGv7Rmos4Ip_TZ-v8QjLl5cyhbfpOk-QjPvI8SOgPsgB5PESfrSTcIGTgGWjs13ow6dL-p82AeZwyUBI3dHcQt4pi1t33bufEm-QQX9PGeaNSyeEdYfVDHXsL6AKLGRsOGnoD0lYH2miDwuK5KcTXL9olLVe9Bqrej8q2rAs6FWCw0VAH0yBOlVsT1NaxPhE_uTp0ae9mEvESEAdYhImLA9KNcPx1YII8A2QaFBzKzu-_5q138tAmgk4Elwy43aru
# ['The Vintage Cafe',
#  'Creek and Cella',
#  'Holey Moley Golf Club Newtown',
#  'Argie BarGee',
#  'Cafe Claire',
#  'Odyssey Bar Restaurant',
#  'Gurdys',
# ...

# %%
# for result in result_1_bar_marr:
#     db.bars_sydney.insert_one(result)

# %%
# for result in result_2_bars_marr:
#     db.bars_sydney.insert_one(result)

# %%
# for result in result_3_bars_marr:
#     db.bars_sydney.insert_one(result)

# %%
#bars in sydney

# %%
# bottle_shop_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=5000&type=liquor_store"
# kc_bottle_shops = requests.get(bottle_shop_url).json()

# print(sydney_bottle_shops['next_page_token'])

# for x in range(2):
init_bars_syd_url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=3000&type=bar"

kc_bars = requests.get(init_bars_syd_url).json()

for bars in kc_bars:
#             print(kc_bottle_shops)
#             print('--------------------------------------')
#             print(kc_bottle_shops['next_page_token'])
            next_bars_syd_url = init_bars_syd_url + ( "&pagetoken=" + kc_bars['next_page_token'])
            #second page url 
#             print('--------------------------------------')
#             print(next_bottle_shop_url)
#             print('--------------------------------------')
            next_bars_syd_url = f'{next_bars_syd_url}'

            
# next_kc_bottle_shops = requests.get(init_bottle_shop_url + ( "&pagetoken=" + kc_bottle_shops['next_page_token'])).json()
            
        
result_1_bars_syd = kc_bars['results']
result_1_bars_syd

name_bars_syd =  [d['name'] for d in result_1_bars_syd]
name_bars_syd
# Out:
# ['QT Sydney',
#  'Sir Stamford at Circular Quay',
#  'Wake Up! Sydney',
#  'Amora Hotel',
#  'Castlereagh Boutique Hotel',
#  'Travelodge Hotel Sydney Wynyard',
#  'Ovolo Woolloomooloo',
#  'Ovolo 1888 Darling Harbour',
#  'Base Backpackers Sydney',
#  'Adria Bar Restaurant',
#  'Georges Mediterranean Bar & Grill',
#  'Captain Cook Hotel',
#  'Rockpool Bar & Grill',
#  'Shakespeare Hotel',
#  'The Bavarian York St.',
#  'Hotel Downing',
#  'Prime Steak Restaurant',
#  'China Doll',
#  'The Hero of Waterloo',
#  'Toko Sydney']

# %%
next_bars_syd_url = f'{next_bars_syd_url}'
kc_bars_2 = requests.get(next_bars_syd_url).json()
print(next_bars_syd_url)
# marr_bars_2

result_2_kc_bars = kc_bars_2['results']
result_2_kc_bars

name_kc_bars_2 =  [d['name'] for d in result_2_kc_bars]
name_kc_bars_2
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=3000&type=bar&pagetoken=CqQCGAEAALHyRWcgaU3p0ndeP71NM91M-IcsiZQeHQ8_elFKohtfmObRZqw__dNRFI1Q5s6NXyunqapwAmK_raTpMo93KyYVuQeJhSVOFqlYKIpS3Ne_5aSt8IxMrP82N3LD8jmxsWyi1aaPeydP3EQShxC4Bzr9s-_rL0Hyds4Ozu_A3tv6qwS8k20y_ylW8o73xxvhzMUufY2a7b1bbdvFLQx7IpjWu7-lm6Z7jrovUyyX-WennVo2XhzImSmp1RMQ2VJSVNZO1WPl3AT65NqCyk102V6nQSxhf4VuDH3vLZCHZLJ2d4s3xe86BYcHoN8EAXjZ4B3gSdRqFSnDmjGFvatRkielzm24tLghwrg7DBcABrLl8mehiKlmtM5W99DV1BOFlRIQRmv9XSlMX9Uep1QIfIK2PRoU_YS71LnG4JDOn6E3LV4L3tsKRvw
# ['Redoak Boutique Beer Cafe',
#  'The Winery',
#  'Chamberlain Hotel (C-Bar)',
#  'Cafe Sydney',
#  'The Grand Hotel',
#  'Sienna Marina',
#  'Flying Fish',
#  "Grandma's Bar",
#  'Ms.G’s',
#  'Verde Restaurant',
#  'The Beresford',
#  'The Tilbury Hotel',
#  'The Glenmore Hotel',
#  'El Loco at Slip Inn',
#  'The Captains Balcony',
#  'O Bar and Dining',
#  'Empire Hotel',
# ...

# %%
next_bars_syd_url = init_bars_syd_url + ( "&pagetoken=" + kc_bars_2['next_page_token'])
print(next_bars_syd_url)
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=3000&type=bar&pagetoken=CsQDuAEAALB_K6wx_sLCjEDLyVUt4fkPgkCniDVb95nu_y8qPI_awaIoVFvkqBKgRCo-qJSVSKmYwkanE9KN5uELq_c3cpVBzsK2m0A1Q5TIDjI8VaXhXxFJobo8s0BA8GgXszKGBWCMXLE4KLL-u3nuhU4wx8Q8tKWZwl2svjYwTp0ibsWNKFsOqRMnCt5xvbo16Sw1sL6EPFWfr7PM4SM5SARaiDTGYevE-Sfpd4Yer1VJeYL0RBetH1QOkdespWle8auTy2W4gMcowa1Qfj1yPzZX25hPr1-zuEBrGa26gSprPmqReiaBssA5rpwDECrJwCh6Dm0AktS1exiYU3h6tSH_eogWpBCHyzLVct2ZiVzHJQWViFyrimH9BNspfMXqwE40oUh5nATsEykY_pJC_NbCiksdrkXn_s4XbpCEDsH2rB8bi0OXH4kgwywna82twgol-zbKkMbS7Ah6i-QgOP1difB0zD2K8z6JeMtrtfDJu9Q5uKlws_amA9ZTtZK0VwAW-4H-P0VIvjHbMoQlZzl3p-SJ48D4KXkkJL4ozrnGAMH5zXZq7G-ZrK5UkPReVsKXBhy5r1Mlm54lL5IdpZ2w1w0SEHY0OUoV4oVcoXBEqvCRMwsaFL_meClA1AkbJfwGYArrX8q8DfWW

# %%
next_bars_syd_url = f'{next_bars_syd_url}'
kc_bars_3 = requests.get(next_bars_syd_url).json()
print(next_bars_syd_url)
# marr_bars_2

result_3_kc_bars = kc_bars_3['results']
result_3_kc_bars

name_kc_bars_3 =  [d['name'] for d in result_3_kc_bars]
name_kc_bars_3
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?key=AIzaSyA31Y4cfs7pVmwQ_a4S0k1kyYwAhav7F7E&location=-33.8734,151.2242&radius=3000&type=bar&pagetoken=CsQDuAEAALB_K6wx_sLCjEDLyVUt4fkPgkCniDVb95nu_y8qPI_awaIoVFvkqBKgRCo-qJSVSKmYwkanE9KN5uELq_c3cpVBzsK2m0A1Q5TIDjI8VaXhXxFJobo8s0BA8GgXszKGBWCMXLE4KLL-u3nuhU4wx8Q8tKWZwl2svjYwTp0ibsWNKFsOqRMnCt5xvbo16Sw1sL6EPFWfr7PM4SM5SARaiDTGYevE-Sfpd4Yer1VJeYL0RBetH1QOkdespWle8auTy2W4gMcowa1Qfj1yPzZX25hPr1-zuEBrGa26gSprPmqReiaBssA5rpwDECrJwCh6Dm0AktS1exiYU3h6tSH_eogWpBCHyzLVct2ZiVzHJQWViFyrimH9BNspfMXqwE40oUh5nATsEykY_pJC_NbCiksdrkXn_s4XbpCEDsH2rB8bi0OXH4kgwywna82twgol-zbKkMbS7Ah6i-QgOP1difB0zD2K8z6JeMtrtfDJu9Q5uKlws_amA9ZTtZK0VwAW-4H-P0VIvjHbMoQlZzl3p-SJ48D4KXkkJL4ozrnGAMH5zXZq7G-ZrK5UkPReVsKXBhy5r1Mlm54lL5IdpZ2w1w0SEHY0OUoV4oVcoXBEqvCRMwsaFL_meClA1AkbJfwGYArrX8q8DfWW
# ['Since I Left You (SILY)',
#  'The Baxter Inn',
#  'Ash St. Cellar',
#  'Fix Wine Bar + Restaurant',
#  'Harts Pub',
#  'Establishment Bar',
#  'Four in Hand Pub',
# ...

# %%
for result in result_1_bars_syd:
    db.bars_sydney.insert_one(result)

# %%
for result in result_2_kc_bars:
    db.bars_sydney.insert_one(result)

# %%
for result in result_3_kc_bars:
    db.bars_sydney.insert_one(result)
